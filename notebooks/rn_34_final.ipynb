# %% [markdown]
# # Custom ResNet-34 with Dropout on CIFAR-10 Dataset

# %% [markdown]
# Importing the required Python libraries

# %%
import math
import os
import sys
import time

import torch
from torch.utils.data import random_split, DataLoader
import torchvision
from torchvision.utils import make_grid
import torchvision.transforms as transforms

import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Dataset Preparation
#
# We download the CIFAR-10 train and test datasets from torchvision. The datasets are normalized and transformations applied. Additionally, for the training dataset, we will apply Random Crops and Random Horizontal Flips to improve model generalization.

# %%
# Mean, Standard Deviation of CIFAR-10 dataset channels
data_stats = (
    (0.49139968, 0.48215827, 0.44653124),
    (0.24703233, 0.24348505, 0.26158768)
)

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Random crops
    transforms.RandomHorizontalFlip(), # Random horizontal flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_stats, inplace=True) # Output in range [-1, 1]
])

val_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(*data_stats, inplace=True)
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_stats, inplace=True)
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)

# %% [markdown]
# Now we create data loaders to retrieve images in batches. The batch size for the training loader is set to 128 images, while for the test loader, we choose a batch size of 100 images. Additionally, we will use a batch size of 100 images for the validation set as well. The training and validation split is 80-20.

# %%
validation_ratio = 0.2
train_size = int((1 - validation_ratio) * len(train_dataset))
val_size = len(train_dataset) - train_size

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# %%
train_batch_size = 128
test_batch_size = 100
val_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=3, pin_memory=True)
val_dl = DataLoader(val_dataset, val_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# The following functions are to display a batch of images from the dataset, and to denormalize the pixels values to bring them back into the range (0,1) in order to visualize the images.

# %%
def visualize_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_stats)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

# %%
visualize_batch(train_dl)

# %% [markdown]
# The following are helper functions to set the device to GPU/CPU depending on availability, and move the model to GPU.

# %%
def get_default_device():
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')


# Move tensors to chosen device
def to_device(data, device):
  if isinstance(data, (list, tuple)):
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)


# Wrap a dataloader to move data to a device
class DeviceDataLoader():
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    for b in self.dl:
      yield to_device(b, self.device)

  # Number of batches
  def __len__(self):
    return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
test_dl = DeviceDataLoader(test_dl, device)
val_dl = DeviceDataLoader(val_dl, device)

# %% [markdown]
# ### ResNet Architecture

# %% [markdown]
# We have added a dropout layer for regularization and reduced the channel sizes to contain the number of parameters of the model.

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.dropout = nn.Dropout(0.2) # Adding Dropout Layer

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.dropout(self.bn2(self.conv2(out))) # Adding Dropout in Forward
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 96, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 192, num_blocks[3], stride=2)
    self.linear = nn.Linear(192*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1] * (num_blocks - 1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

# %% [markdown]
# ### ResNet34

# %%
model = ResNet34()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#            Dropout-7           [-1, 64, 32, 32]               0
#         BasicBlock-8           [-1, 64, 32, 32]               0
#             Conv2d-9           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-10           [-1, 64, 32, 32]             128
#            Conv2d-11           [-1, 64, 32, 32]          36,864
#       BatchNorm2d
#       BatchNorm2d-70            [-1, 128, 8, 8]             256
#           Dropout-71            [-1, 128, 8, 8]               0
#        BasicBlock-72            [-1, 128, 8, 8]               0
#            Conv2d-73            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-74            [-1, 128, 8, 8]             256
#            Conv2d-75            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-76            [-1, 128, 8, 8]             256
#           Dropout-77            [-1, 128, 8, 8]               0
#        BasicBlock-78            [-1, 128, 8, 8]               0
#            Conv2d-79            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-80            [-1, 128, 8, 8]             256
#            Conv2d-81            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-82            [-1, 128, 8, 8]             256
#           Dropout-83            [-1, 128, 8, 8]               0
#        BasicBlock-84            [-1, 128, 8, 8]               0
#            Conv2d-85            [-1, 192, 4, 4]         221,184
#       BatchNorm2d-86            [-1, 192, 4, 4]             384
#            Conv2d-87            [-1, 192, 4, 4]         331,776
#       BatchNorm2d-88            [-1, 192, 4, 4]             384
#           Dropout-89            [-1, 192, 4, 4]               0
#            Conv2d-90            [-1, 192, 4, 4]          24,576
#       BatchNorm2d-91            [-1, 192, 4, 4]             384
#        BasicBlock-92            [-1, 192, 4, 4]               0
#            Conv2d-93            [-1, 192, 4, 4]         331,776
#       BatchNorm2d-94            [-1, 192, 4, 4]             384
#            Conv2d-95            [-1, 192, 4, 4]         331,776
#       BatchNorm2d-96            [-1, 192, 4, 4]             384
#           Dropout-97            [-1, 192, 4, 4]               0
#        BasicBlock-98            [-1, 192, 4, 4]               0
#            Conv2d-99            [-1, 192, 4, 4]         331,776
#      BatchNorm2d-100            [-1, 192, 4, 4]             384
#           Conv2d-101            [-1, 192, 4, 4]         331,776
#      BatchNorm2d-102            [-1, 192, 4, 4]             384
#          Dropout-103            [-1, 192, 4, 4]               0
#       BasicBlock-104            [-1, 192, 4, 4]               0
#           Linear-105                   [-1, 10]           1,930
# ================================================================
# Total params: 4,525,066
# Trainable params: 4,525,066
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 17.72
# Params size (MB): 17.26
# Estimated Total Size (MB): 34.99
# ----------------------------------------------------------------

# %% [markdown]
# ## Model Training

# %% [markdown]
# * Number of Epochs: 100
# * Learning Rate: 0.1
# * Scheduler: CosineAnnealingLR
# * Momentum: 0.9
# * Weight Decay: 5e-4
# * Loss: CrossEntropyLoss
# * Optimizer: SGD

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_test_acc = 0
best_val_acc = 0

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
# Helper function to get Learning Rate
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)

  model.train()
  train_loss = 0
  correct = 0
  total = 0

  for batch_idx, (inputs, targets) in enumerate(train_dl):
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    avg_train_loss = train_loss / (batch_idx + 1)
    train_acc = 100. * correct / total

  return avg_train_loss, train_acc, get_lr(optimizer)

# %%
def validate(epoch):

  global best_val_acc

  model.eval()
  val_loss = 0
  correct = 0
  total = 0

  with torch.no_grad():
      for batch_idx, (inputs, targets) in enumerate(val_dl):
          outputs = model(inputs)
          loss = criterion(outputs, targets)

          val_loss += loss.item()
          _, predicted = outputs.max(1)
          total += targets.size(0)
          correct += predicted.eq(targets).sum().item()

  # Save checkpoint
  val_acc = 100. * correct / total
  if val_acc > best_val_acc:
    print('Saving checkpoint...')
    state = {
      'net': model.state_dict(),
      'acc': val_acc,
      'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/resnet_34_dropout_best.pth')
    best_val_acc = val_acc

  avg_val_loss = val_loss / (batch_idx + 1)

  return avg_val_loss, val_acc

# %%
def test(epoch):

  global best_test_acc

  model.eval()
  test_loss = 0
  correct = 0
  total = 0

  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()

  acc = 100. * correct / total
  if acc > best_test_acc:
    best_test_acc = acc

  avg_test_loss = test_loss / (batch_idx + 1)

  return avg_test_loss, acc

# %%
train_losses = []
train_accuracies = []
train_lrs = []

val_losses = []
val_accuracies = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_val_loss, epoch_val_accuracy = validate(epoch)
  val_losses.append(epoch_val_loss)
  val_accuracies.append(epoch_val_accuracy)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step() # adjust LR

  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% \n"
        f"Validation Loss: {epoch_val_loss:.3f} | Validation Accuracy: {epoch_val_accuracy:.3f}% \n"
        f"Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Saving checkpoint...
# Train Loss: 1.829 | Train Accuracy: 32.208%
# Validation Loss: 1.716 | Validation Accuracy: 38.580%
# Test Loss: 1.685 | Test Accuracy: 39.910%
#
# Epoch: 2
# Saving checkpoint...
# Train Loss: 1.414 | Train Accuracy: 47.840%
# Validation Loss: 1.325 | Validation Accuracy: 51.830%
# Test Loss: 1.259 | Test Accuracy: 54.330%
#
# Epoch: 3
# Saving checkpoint...
# Train Loss: 1.185 | Train Accuracy: 57.532%
# Validation Loss: 1.159 | Validation Accuracy: 58.850%
# Test Loss: 1.110 | Test Accuracy: 60.110%
# Train Loss: 0.007 | Train Accuracy: 99.812%
# Validation Loss: 0.228 | Validation Accuracy: 94.250%
# Test Loss: 0.213 | Test Accuracy: 94.830%
#
# Epoch: 100
# Train Loss: 0.006 | Train Accuracy: 99.868%
# Validation Loss: 0.228 | Validation Accuracy: 94.170%
# Test Loss: 0.214 | Test Accuracy: 94.740%

# %%
print(f"Best Validation Accuracy: {best_val_acc:.3f}%")
# Out:
# Best Validation Accuracy: 94.290%

# %%
print(f"Best Test Accuracy: {best_test_acc: .3f}%")
# Out:
# Best Test Accuracy:  94.830%

# %% [markdown]
# ## Visualizations

# %%
# Evaluate model on test set to generate predictions, calculate confusion matrix, and visualize it

from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = []
y_true = []
model.eval()
with torch.no_grad():
    for images, labels in test_dl:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        y_pred.extend(predicted.view(-1).tolist())
        y_true.extend(labels.view(-1).tolist())

conf_matrix = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs #epochs')

# %%
def plot_accuracies(train_accuracies, val_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(val_accuracies, label='Validation Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs #epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs #epochs')

# %%
def plot_val_losses(train_losses, val_losses):
    plt.plot(train_losses, label='Train Losses')
    plt.plot(val_losses, label='Validation Losses')  # Added validation loss
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.title('Training vs Validation Loss')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %% [markdown]
# ### Save the model

# %%
print('==> Saving final model...')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_test_acc' : best_test_acc,
    'best_val_acc' : best_val_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'val_loss' : val_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/rn_34_final.pth')
# Out:
# ==> Saving final model...

# %% [markdown]
# ## Make predictions for the given test dataset

# %%
import numpy as np
import pickle
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset

def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

cifar10_dir = './data/cifar-10-batches-py'

# Load label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = [label.decode('utf-8') for label in meta_data_dict[b'label_names']]  # Decode bytes to string

# Load given test data
test_batch = load_cifar_batch('./cifar_test_nolabel.pkl')
test_images = np.array(test_batch[b'data'])

data_stats = (
    (0.49139968, 0.48215827, 0.44653124),
    (0.24703233, 0.24348505, 0.26158768)
)

# transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_stats, inplace=True)
])

# Apply transformations to test images
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Create a dataset from test images
test_dataset = TensorDataset(augmented_test_images)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=2, pin_memory=True)

# Load the trained model
model = ResNet34()

checkpoint = torch.load('./checkpoint/rn_34_best.pth')

# Check keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model = model.to(device)
augmented_test_images = augmented_test_images.to(device)

# Evaluate the model on test data
model.eval()

predictions = []

# Process in batches
with torch.no_grad():
    for batch in test_loader:
        batch = batch[0].to(device)  # Move batch to GPU
        outputs = model(batch)  # Forward pass
        _, batch_preds = torch.max(outputs, 1)  # Get predicted class
        predictions.extend(batch_preds.cpu().numpy())  # Move predictions to CPU

# Convert predictions to a NumPy array
predicted = np.array(predictions)

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()])
    plt.axis('off')
plt.show()

# Save the output in csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted}
output_df = pd.DataFrame(output_data)
output_df.to_csv('rn_34_output.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

# %%
predicted
# Out:
# array([6, 1, 8, ..., 0, 5, 1])

# %%
predicted_labels = [classes[i] for i in predicted]
print(predicted_labels)

for idx, label in enumerate(predicted_labels):
    print(f"Image {idx}: Predicted Class = {label}")
# Out:
# ['frog', 'car', 'ship', 'frog', 'truck', 'cat', 'bird', 'bird', 'truck', 'dog', 'bird', 'plane', 'ship', 'ship', 'horse', 'plane', 'dog', 'ship', 'dog', 'ship', 'truck', 'horse', 'horse', 'deer', 'frog', 'horse', 'deer', 'car', 'cat', 'cat', 'car', 'cat', 'cat', 'cat', 'cat', 'horse', 'bird', 'deer', 'horse', 'deer', 'car', 'frog', 'ship', 'truck', 'truck', 'truck', 'car', 'horse', 'dog', 'horse', 'deer', 'frog', 'car', 'car', 'bird', 'car', 'car', 'horse', 'truck', 'cat', 'deer', 'bird', 'ship', 'car', 'frog', 'cat', 'frog', 'plane', 'dog', 'truck', 'plane', 'frog', 'bird', 'cat', 'dog', 'plane', 'plane', 'truck', 'ship', 'dog', 'bird', 'cat', 'ship', 'deer', 'car', 'cat', 'horse', 'frog', 'car', 'cat', 'plane', 'dog', 'ship', 'dog', 'car', 'frog', 'horse', 'ship', 'car', 'dog', 'cat', 'dog', 'deer', 'bird', 'car', 'plane', 'truck', 'car', 'horse', 'truck', 'horse', 'cat', 'deer', 'ship', 'truck', 'deer', 'car', 'dog', 'horse', 'car', 'truck', 'frog', 'bird', 'ship', 'ship', 'truck', 'truck', 'deer', 'horse', 'plane', 'deer', 'plane', 'bird', 'deer', 'ship', 'car', 'car', 'deer', 'deer', 'cat', 'cat', 'ship', 'dog', 'dog', 'ship', 'bird', 'plane', 'car', 'ship', 'frog', 'horse', 'cat', 'ship', 'frog', 'car', 'frog', 'frog', 'bird', 'dog', 'plane', 'frog', 'ship', 'horse', 'bird', 'cat', 'plane', 'bird', 'bird', 'cat', 'truck', 'cat', 'ship', 'bird', 'horse', 'dog', 'bird', 'deer', 'car', 'horse', 'truck', 'truck', 'bird', 'bird', 'dog', 'truck', 'cat', 'frog', 'truck', 'frog', 'car', 'dog', 'truck', 'truck', 'cat', 'horse', 'plane', 'car', 'car', 'bird', 'bird', 'truck', 'dog', 'ship', 'car', 'ship', 'cat', 'truck', 'horse', 'deer', 'ship', 'ship', 'dog', 'bird', 'car', 'cat', 'cat', 'horse', 'horse', 'frog', 'horse', 'dog', 'ship', 'car', 'ship', 'deer', 'horse', 'horse', 'dog', 'deer', 'truck', 'car', 'plane', 'dog', 'bird', 'bird', 'frog', 'cat', 'cat', 'horse', 'ship', 'horse', 'plane', 'ship', 'ship', 'horse', 'cat', 'car', 'dog', 'horse', 'ship', 'cat', 'frog', 'horse', 'dog', 'cat', 'dog', 'truck', 'dog', 'truck', 'car', 'truck', 'deer', 'car', 'cat', 'bird', 'horse', 'deer', 'ship', 'dog', 'truck', 'truck', 'frog', 'bird', 'car', 'bird', 'dog', 'car', 'bird', 'cat', 'plane', 'cat', 'truck', 'car', 'plane', 'plane', 'plane', 'dog', 'dog', 'cat', 'dog', 'truck', 'ship', 'plane', 'plane', 'bird', 'ship', 'ship', 'dog', 'dog', 'ship', 'car', 'deer', 'frog', 'plane', 'car', 'ship', 'cat', 'ship', 'deer', 'ship', 'deer', 'horse', 'car', 'horse', 'cat', 'cat', 'horse', 'dog', 'ship', 'truck', 'bird', 'frog', 'truck', 'horse', 'ship', 'frog', 'horse', 'bird', 'horse', 'deer', 'car', 'horse', 'car', 'car', 'ship', 'plane', 'ship', 'car', 'horse', 'cat', 'dog', 'dog', 'cat', 'car', 'bird', 'dog', 'deer', 'horse', 'plane', 'cat', 'plane', 'frog', 'ship', 'deer', 'plane', 'dog', 'truck', 'plane', 'plane', 'bird', 'deer', 'dog', 'frog', 'cat', 'horse', 'car', 'frog', 'truck', 'frog', 'horse', 'cat', 'dog', 'frog', 'dog', 'dog', 'ship', 'ship', 'car', 'frog', 'truck', 'car', 'cat', 'horse', 'truck', 'ship', 'cat', 'frog', 'cat', 'plane', 'cat', 'frog', 'dog', 'cat', 'truck', 'horse', 'car', 'bird', 'ship', 'truck', 'car', 'deer', 'cat', 'truck', 'frog', 'ship', 'truck', 'horse', 'deer', 'cat', 'horse', 'frog', 'frog', 'plane', 'horse', 'truck', 'truck', 'cat', 'horse', 'plane', 'dog', 'frog', 'frog', 'car', 'ship', 'plane', 'dog', 'dog', 'truck', 'frog', 'dog', 'bird', 'frog', 'truck', 'deer', 'car', 'truck', 'horse', 'dog', 'cat', 'car', 'plane', 'horse', 'ship', 'dog', 'dog', 'frog', 'bird', 'truck', 'frog', 'dog', 'cat', 'ship', 'truck', 'plane', 'ship', 'horse', 'bird', 'plane', 'ship', 'cat', 'ship', 'cat', 'frog', 'horse', 'frog', 'dog', 'dog', 'frog', 'frog', 'ship', 'cat', 'bird', 'plane', 'plane', 'truck', 'plane', 'deer', 'deer', 'car', 'deer', 'dog', 'ship', 'cat', 'cat', 'plane', 'car', 'horse', 'ship', 'car', 'dog', 'horse', 'plane', 'bird', 'dog', 'deer', 'dog', 'ship', 'car', 'frog', 'deer', 'truck', 'truck', 'car',  ...
# Image 0: Predicted Class = frog
# Image 1: Predicted Class = car
# Image 2: Predicted Class = ship
# Image 3: Predicted Class = frog
# Image 4: Predicted Class = truck
# Image 5: Predicted Class = cat
# Image 6: Predicted Class = bird
# Image 7: Predicted Class = bird
# Image 8: Predicted Class = truck
# Image 9: Predicted Class = dog
# Image 10: Predicted Class = bird
# Image 11: Predicted Class = plane
# Image 12: Predicted Class = ship
# Image 13: Predicted Class = ship
# Image 14: Predicted Class = horse
# Image 15: Predicted Class = plane
# Image 16: Predicted Class = dog
# Image 17: Predicted Class = ship
# Image 18: Predicted Class = dog
# Image 19: Predicted Class = ship
# Image 20: Predicted Class = truck
# Image 21: Predicted Class = horse
# Image 22: Predicted Class = horse
# Image 23: Predicted Class = deer
# Image 24: Predicted Class = frog
# Image 25: Predicted Class = horse
# Image 26: Predicted Class = deer
# Image 27: Predicted Class = car
# Image 28: Predicted Class = cat
# Image 29: Predicted Class = cat
# Image 30: Predicted Class = car
# Image 31: Predicted Class = cat
# Image 32: Predicted Class = cat
# Image 33: Predicted Class = cat
# Image 34: Predicted Class = cat
# Image 35: Predicted Class = horse
# Image 36: Predicted Class = bird
# Image 37: Predicted Class = deer
# Image 38: Predicted Class = horse
# Image 39: Predicted Class = deer
# Image 40: Predicted Class = car
# Image 41: Predicted Class = frog
# Image 42: Predicted Class = ship
# Image 43: Predicted Class = truck
# Image 44: Predicted Class = truck
# Image 45: Predicted Class = truck
# Image 46: Predicted Class = car
# Image 47: Predicted Class = horse
# Image 48: Predicted Class = dog
# Image 49: Predicted Class = horse
# Image 50: Predicted Class = deer
# Image 51: Predicted Class = frog
# Image 52: Predicted Class = car
# Image 53: Predicted Class = car
# Image 54: Predicted Class = bird
# Image 55: Predicted Class = car
# Image 56: Predicted Class = car
# Image 57: Predicted Class = horse
# Image 58: Predicted Class = truck
# Image 59: Predicted Class = cat
# Image 60: Predicted Class = deer
# Image 61: Predicted Class = bird
# Image 62: Predicted Class = ship
# Image 63: Predicted Class = car
# Image 64: Predicted Class = frog
# Image 9934: Predicted Class = dog
# Image 9935: Predicted Class = plane
# Image 9936: Predicted Class = frog
# Image 9937: Predicted Class = ship
# Image 9938: Predicted Class = ship
# Image 9939: Predicted Class = frog
# Image 9940: Predicted Class = deer
# Image 9941: Predicted Class = ship
# Image 9942: Predicted Class = plane
# Image 9943: Predicted Class = frog
# Image 9944: Predicted Class = car
# Image 9945: Predicted Class = dog
# Image 9946: Predicted Class = ship
# Image 9947: Predicted Class = dog
# Image 9948: Predicted Class = dog
# Image 9949: Predicted Class = car
# Image 9950: Predicted Class = cat
# Image 9951: Predicted Class = car
# Image 9952: Predicted Class = plane
# Image 9953: Predicted Class = frog
# Image 9954: Predicted Class = plane
# Image 9955: Predicted Class = deer
# Image 9956: Predicted Class = deer
# Image 9957: Predicted Class = cat
# Image 9958: Predicted Class = frog
# Image 9959: Predicted Class = frog
# Image 9960: Predicted Class = frog
# Image 9961: Predicted Class = truck
# Image 9962: Predicted Class = horse
# Image 9963: Predicted Class = bird
# Image 9964: Predicted Class = frog
# Image 9965: Predicted Class = dog
# Image 9966: Predicted Class = deer
# Image 9967: Predicted Class = plane
# Image 9968: Predicted Class = car
# Image 9969: Predicted Class = plane
# Image 9970: Predicted Class = bird
# Image 9971: Predicted Class = plane
# Image 9972: Predicted Class = plane
# Image 9973: Predicted Class = dog
# Image 9974: Predicted Class = horse
# Image 9975: Predicted Class = truck
# Image 9976: Predicted Class = horse
# Image 9977: Predicted Class = frog
# Image 9978: Predicted Class = frog
# Image 9979: Predicted Class = bird
# Image 9980: Predicted Class = truck
# Image 9981: Predicted Class = horse
# Image 9982: Predicted Class = car
# Image 9983: Predicted Class = bird
# Image 9984: Predicted Class = horse
# Image 9985: Predicted Class = plane
# Image 9986: Predicted Class = car
# Image 9987: Predicted Class = dog
# Image 9988: Predicted Class = truck
# Image 9989: Predicted Class = cat
# Image 9990: Predicted Class = bird
# Image 9991: Predicted Class = truck
# Image 9992: Predicted Class = bird
# Image 9993: Predicted Class = cat
# Image 9994: Predicted Class = dog
# Image 9995: Predicted Class = horse
# Image 9996: Predicted Class = plane
# Image 9997: Predicted Class = plane
# Image 9998: Predicted Class = dog
# Image 9999: Predicted Class = car

# %% [markdown]
# ### Visualizing the predictions

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Convert counts to a list for visualization
class_counts = Counter(predicted)

# Sort labels in CIFAR-10 order
sorted_classes = [classes[i] for i in class_counts.keys()]
sorted_counts = [class_counts[i] for i in class_counts.keys()]

plt.figure(figsize=(10,5))
plt.bar(sorted_classes, sorted_counts, color='skyblue')
plt.xlabel('Classes')
plt.ylabel('Number of Predictions')
plt.title('Distribution of Predicted Classes')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
from collections import Counter

class_counts = Counter(predicted)

# Print counts for each class
for class_idx, count in class_counts.items():
    print(f"{classes[class_idx]}: {count}")
# Out:
# frog: 882
# car: 1027
# ship: 1003
# truck: 1053
# cat: 1062
# bird: 989
# dog: 1129
# plane: 902
# horse: 1007
# deer: 946
